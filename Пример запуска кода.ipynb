# %% [markdown]
# # Подготавливаем скрипт к запуску

# %% [markdown]
# ### Инструкция по запуску скрипта также лежит в readme

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Запускаем скрипт

# %% [markdown]
# python main.py --files resourses/math.csv resourses/programming.csv resourses/physics.csv  --output report.txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Для Запуска тестов запустить

# %% [markdown]
# ![image.png](attachment:image.png)
